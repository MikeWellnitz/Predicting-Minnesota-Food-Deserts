# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
data_df = pd.read_excel('FoodAccessResearchAtlasData2019.xlsx')
data_df.head()

# %%
mn_df = data_df[data_df['State'] == 'Minnesota']
mn_df
# Out:
#        CensusTract      State                  County  Urban  Pop2010  \
# 35210  27003050501  Minnesota            Anoka County      1     3041
# 35211  27003050607  Minnesota            Anoka County      1     4491
# 35212  27003051400  Minnesota            Anoka County      1     4868
# 35213  27003051501  Minnesota            Anoka County      1     3005
# 35214  27005450500  Minnesota           Becker County      1     4148
# ...            ...        ...                     ...    ...      ...
# 36539  27171101200  Minnesota           Wright County      0     3931
# 36540  27173970100  Minnesota  Yellow Medicine County      0     3371
# 36541  27173970200  Minnesota  Yellow Medicine County      0     2520
# 36542  27173970300  Minnesota  Yellow Medicine County      0     2517
# 36543  27173970400  Minnesota  Yellow Medicine County      0     2030
#
#        OHU2010  GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 35210     1447                  0     252.0  8.286748                  1  ...
# 35211     1813                  0      32.0  0.712536                  1  ...
# 35212     1966                  0       0.0  0.000000                  1  ...
# 35213     1316                  0       0.0  0.000000                  1  ...
# 35214     1804                  0     188.0  4.532305                  1  ...
# ...        ...                ...       ...       ...                ...  ...
# 36539     1518                  0      60.0  1.526329                  0  ...
# 36540     1379                  0     118.0  3.500445                  0  ...
# 36541     1075                  0     122.0  4.841270                  0  ...
# 36542     1044                  0      49.0  1.946762                  0  ...
# 36543      794                  0       1.0  0.049261                  1  ...
#
#        TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  \
# 35210         605.0      2732.0       130.0        26.0         0.0
# 35211         573.0      3819.0       288.0        84.0         2.0
# 35212         451.0      3229.0       797.0       247.0         2.0
# 35213         528.0      1936.0       582.0       139.0         1.0
# 35214         643.0      3600.0        44.0        48.0         1.0
# ...             ...         ...         ...         ...         ...
# 36539         526.0      3841.0        17.0        10.0         2.0
# 36540         626.0      2955.0         7.0        15.0         1.0
# 36541         641.0      2479.0         6.0         7.0         0.0
# 36542         467.0      2452.0         2.0         5.0         0.0
# 36543         297.0      1920.0         1.0         6.0         5.0
#
#        TractAIAN  TractOMultir  TractHispanic  TractHUNV  TractSNAP
# 35210       49.0         104.0          136.0      244.0      198.0
# 35211       47.0         251.0          178.0      132.0      247.0
# 35212       87.0         506.0          577.0      118.0      165.0
# 35213       33.0         314.0          372.0      331.0      309.0
# 35214      258.0         197.0           74.0      205.0      480.0
# ...          ...           ...            ...        ...        ...
# 36539        9.0          52.0          110.0       59.0      110.0
# 36540      271.0         122.0          119.0       87.0      136.0
# 36541        1.0          27.0           44.0       63.0      105.0
# 36542       11.0          47.0           64.0       30.0       67.0
# 36543       31.0          67.0          170.0       30.0       58.0
#
# [1334 rows x 147 columns]

# %%
grouped_df = mn_df[["County", "Urban", "Pop2010", "OHU2010",
                            "GroupQuartersFlag", "NUMGQTRS", "PCTGQTRS", "HUNVFlag", "LowIncomeTracts", 
                            "PovertyRate", "MedianFamilyIncome", "TractLOWI", "TractKids", "TractSeniors", 
                            "TractWhite", "TractBlack", "TractAsian", "TractNHOPI", "TractAIAN", 
                            "TractOMultir", "TractHispanic", "TractHUNV", "TractSNAP", "LAhalfand10"]]
grouped_df.head()
# Out:
#               County  Urban  Pop2010  OHU2010  GroupQuartersFlag  NUMGQTRS  \
# 35210   Anoka County      1     3041     1447                  0     252.0
# 35211   Anoka County      1     4491     1813                  0      32.0
# 35212   Anoka County      1     4868     1966                  0       0.0
# 35213   Anoka County      1     3005     1316                  0       0.0
# 35214  Becker County      1     4148     1804                  0     188.0
#
#        PCTGQTRS  HUNVFlag  LowIncomeTracts  PovertyRate  ...  TractWhite  \
# 35210  8.286748         1                1    15.465227  ...      2732.0
# 35211  0.712536         1                1     9.216193  ...      3819.0
# 35212  0.000000         1                1    11.160431  ...      3229.0
# 35213  0.000000         1                1    16.223776  ...      1936.0
# 35214  4.532305         1                1    30.311740  ...      3600.0
#
#        TractBlack  TractAsian  TractNHOPI  TractAIAN  TractOMultir  \
# 35210       130.0        26.0         0.0       49.0         104.0
# 35211       288.0        84.0         2.0       47.0         251.0
# 35212       797.0       247.0         2.0       87.0         506.0
# 35213       582.0       139.0         1.0       33.0         314.0
# 35214        44.0        48.0         1.0      258.0         197.0
#
#        TractHispanic  TractHUNV  TractSNAP  LAhalfand10
# 35210          136.0      244.0      198.0            1
# 35211          178.0      132.0      247.0            1
# 35212          577.0      118.0      165.0            1
# 35213          372.0      331.0      309.0            1
# 35214           74.0      205.0      480.0            1
#
# [5 rows x 24 columns]

# %%
grouped_df.isnull().sum()
# Out:
# County                0
# Urban                 0
# Pop2010               0
# OHU2010               0
# GroupQuartersFlag     0
# NUMGQTRS              0
# PCTGQTRS              0
# HUNVFlag              0
# LowIncomeTracts       0
# PovertyRate           0
# MedianFamilyIncome    8
# TractLOWI             0
# TractKids             0
# TractSeniors          0
# TractWhite            0
# TractBlack            0
# TractAsian            0
# TractNHOPI            0
# TractAIAN             0
# TractOMultir          0
# TractHispanic         0
# TractHUNV             0
# TractSNAP             0
# LAhalfand10           0
# dtype: int64

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1334 entries, 35210 to 36543
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   County              1334 non-null   object
#  1   Urban               1334 non-null   int64
#  2   Pop2010             1334 non-null   int64
#  3   OHU2010             1334 non-null   int64
#  4   GroupQuartersFlag   1334 non-null   int64
#  5   NUMGQTRS            1334 non-null   float64
#  6   PCTGQTRS            1334 non-null   float64
#  7   HUNVFlag            1334 non-null   int64
#  8   LowIncomeTracts     1334 non-null   int64
#  9   PovertyRate         1334 non-null   float64
#  10  MedianFamilyIncome  1326 non-null   float64
#  11  TractLOWI           1334 non-null   float64
#  12  TractKids           1334 non-null   float64
#  13  TractSeniors        1334 non-null   float64
#  14  TractWhite          1334 non-null   float64
#  15  TractBlack          1334 non-null   float64
#  16  TractAsian          1334 non-null   float64
#  17  TractNHOPI          1334 non-null   float64
#  18  TractAIAN           1334 non-null   float64
#  19  TractOMultir        1334 non-null   float64
#  20  TractHispanic       1334 non-null   float64
#  21  TractHUNV           1334 non-null   float64
#  22  TractSNAP           1334 non-null   float64
#  23  LAhalfand10         1334 non-null   int64
# dtypes: float64(16), int64(7), object(1)
# memory usage: 260.5+ KB

# %%
grouped_df.loc[(grouped_df["MedianFamilyIncome"].isnull()), ["County", "MedianFamilyIncome"]]
# Out:
#                   County  MedianFamilyIncome
# 35306    Hennepin County                 NaN
# 35318    Hennepin County                 NaN
# 35377    Hennepin County                 NaN
# 35941    Hennepin County                 NaN
# 35943    Hennepin County                 NaN
# 36266      Ramsey County                 NaN
# 36487  Washington County                 NaN
# 36488  Washington County                 NaN

# %%
median = grouped_df.loc[grouped_df["County"] == "Hennepin County"]["MedianFamilyIncome"].median()
median
# Out:
# 95140.5

# %%
grouped_df.loc[(grouped_df["MedianFamilyIncome"].isnull()) & (grouped_df["County"] == "Hennepin County"), "MedianFamilyIncome"] = median

# %%
grouped_df.loc[(grouped_df["MedianFamilyIncome"].isnull()) | (grouped_df["County"] == "Hennepin County"), ["County", "MedianFamilyIncome"]]
# Out:
#                   County  MedianFamilyIncome
# 35229    Hennepin County             56875.0
# 35230    Hennepin County             38542.0
# 35231    Hennepin County             50588.0
# 35232    Hennepin County             66150.0
# 35233    Hennepin County             36098.0
# ...                  ...                 ...
# 35994    Hennepin County            121917.0
# 35995    Hennepin County            173167.0
# 36266      Ramsey County                 NaN
# 36487  Washington County                 NaN
# 36488  Washington County                 NaN
#
# [302 rows x 2 columns]

# %%
median2 = grouped_df.loc[grouped_df["County"] == "Washington County"]["MedianFamilyIncome"].median()
median2
# Out:
# 106858.0

# %%
grouped_df.loc[(grouped_df["MedianFamilyIncome"].isnull()) & (grouped_df["County"] == "Washington County"), "MedianFamilyIncome"] = median2

# %%
median3 = grouped_df.loc[grouped_df["County"] == "Ramsey County"]["MedianFamilyIncome"].median()
median3
# Out:
# 76914.0

# %%
grouped_df.loc[(grouped_df["MedianFamilyIncome"].isnull()) & (grouped_df["County"] == "Ramsey County"), "MedianFamilyIncome"] = median3

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1334 entries, 35210 to 36543
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   County              1334 non-null   object
#  1   Urban               1334 non-null   int64
#  2   Pop2010             1334 non-null   int64
#  3   OHU2010             1334 non-null   int64
#  4   GroupQuartersFlag   1334 non-null   int64
#  5   NUMGQTRS            1334 non-null   float64
#  6   PCTGQTRS            1334 non-null   float64
#  7   HUNVFlag            1334 non-null   int64
#  8   LowIncomeTracts     1334 non-null   int64
#  9   PovertyRate         1334 non-null   float64
#  10  MedianFamilyIncome  1334 non-null   float64
#  11  TractLOWI           1334 non-null   float64
#  12  TractKids           1334 non-null   float64
#  13  TractSeniors        1334 non-null   float64
#  14  TractWhite          1334 non-null   float64
#  15  TractBlack          1334 non-null   float64
#  16  TractAsian          1334 non-null   float64
#  17  TractNHOPI          1334 non-null   float64
#  18  TractAIAN           1334 non-null   float64
#  19  TractOMultir        1334 non-null   float64
#  20  TractHispanic       1334 non-null   float64
#  21  TractHUNV           1334 non-null   float64
#  22  TractSNAP           1334 non-null   float64
#  23  LAhalfand10         1334 non-null   int64
# dtypes: float64(16), int64(7), object(1)
# memory usage: 260.5+ KB

# %%
print(grouped_df.dtypes)
# Out:
# County                 object
# Urban                   int64
# Pop2010                 int64
# OHU2010                 int64
# GroupQuartersFlag       int64
# NUMGQTRS              float64
# PCTGQTRS              float64
# HUNVFlag                int64
# LowIncomeTracts         int64
# PovertyRate           float64
# MedianFamilyIncome    float64
# TractLOWI             float64
# TractKids             float64
# TractSeniors          float64
# TractWhite            float64
# TractBlack            float64
# TractAsian            float64
# TractNHOPI            float64
# TractAIAN             float64
# TractOMultir          float64
# TractHispanic         float64
# TractHUNV             float64
# TractSNAP             float64
# LAhalfand10             int64
# dtype: object

# %%
grouped_df.nunique()
# Out:
# County                  87
# Urban                    2
# Pop2010               1190
# OHU2010                989
# GroupQuartersFlag        2
# NUMGQTRS               278
# PCTGQTRS              1088
# HUNVFlag                 2
# LowIncomeTracts          2
# PovertyRate           1328
# MedianFamilyIncome    1269
# TractLOWI              963
# TractKids              887
# TractSeniors           702
# TractWhite            1161
# TractBlack             503
# TractAsian             424
# TractNHOPI              20
# TractAIAN              167
# TractOMultir           429
# TractHispanic          446
# TractHUNV              336
# TractSNAP              378
# LAhalfand10              2
# dtype: int64

# %%
# Convert population counts to percentages for demographic observations
grouped_df["PctLOWI"] = grouped_df["TractLOWI"] / grouped_df["Pop2010"]
grouped_df["PctKids"] = grouped_df["TractKids"] / grouped_df["Pop2010"]
grouped_df["PctSeniors"] = grouped_df["TractSeniors"] / grouped_df["Pop2010"]
grouped_df["PctWhite"] = grouped_df["TractWhite"] / grouped_df["Pop2010"]
grouped_df["PctBlack"] = grouped_df["TractBlack"] / grouped_df["Pop2010"]
grouped_df["PctAsian"] = grouped_df["TractAsian"] / grouped_df["Pop2010"]
grouped_df["PctNHOPI"] = grouped_df["TractNHOPI"] / grouped_df["Pop2010"]
grouped_df["PctAIAN"] = grouped_df["TractAIAN"] / grouped_df["Pop2010"]
grouped_df["PctOMultir"] = grouped_df["TractOMultir"] / grouped_df["Pop2010"]
grouped_df["PctHispanic"] = grouped_df["TractHispanic"] / grouped_df["Pop2010"]
grouped_df["PctHUNV"] = grouped_df["TractHUNV"] / grouped_df["Pop2010"]
grouped_df["PctSNAP"] = grouped_df["TractSNAP"] / grouped_df["Pop2010"]
# Out:
# C:\Users\joann\AppData\Local\Temp\ipykernel_24644\1782347657.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctLOWI"] = grouped_df["TractLOWI"] / grouped_df["Pop2010"]
# C:\Users\joann\AppData\Local\Temp\ipykernel_24644\1782347657.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctKids"] = grouped_df["TractKids"] / grouped_df["Pop2010"]
# C:\Users\joann\AppData\Local\Temp\ipykernel_24644\1782347657.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctSeniors"] = grouped_df["TractSeniors"] / grouped_df["Pop2010"]
# C:\Users\joann\AppData\Local\Temp\ipykernel_24644\1782347657.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctWhite"] = grouped_df["TractWhite"] / grouped_df["Pop2010"]
# C:\Users\joann\AppData\Local\Temp\ipykernel_24644\1782347657.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctBlack"] = grouped_df["TractBlack"] / grouped_df["Pop2010"]
# C:\Users\joann\AppData\Local\Temp\ipykernel_24644\1782347657.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctAsian"] = grouped_df["TractAsian"] / grouped_df["Pop2010"]
# C:\Users\joann\AppData\Local\Temp\ipykernel_24644\1782347657.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctNHOPI"] = grouped_df["TractNHOPI"] / grouped_df["Pop2010"]
# C:\Users\joann\AppData\Local\Temp\ipykernel_24644\1782347657.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctAIAN"] = grouped_df["TractAIAN"] / grouped_df["Pop2010"]
# C:\Users\joann\AppData\Local\Temp\ipykernel_24644\1782347657.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctOMultir"] = grouped_df["TractOMultir"] / grouped_df["Pop2010"]
# C:\Users\joann\AppData\Local\Temp\ipykernel_24644\1782347657.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctHispanic"] = grouped_df["TractHispanic"] / grouped_df["Pop2010"]
# C:\Users\joann\AppData\Local\Temp\ipykernel_24644\1782347657.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctHUNV"] = grouped_df["TractHUNV"] / grouped_df["Pop2010"]
# C:\Users\joann\AppData\Local\Temp\ipykernel_24644\1782347657.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctSNAP"] = grouped_df["TractSNAP"] / grouped_df["Pop2010"]

# %%
# drop columns with population counts
grouped_df.drop(columns=['TractLOWI','TractKids','TractSeniors','TractWhite','TractBlack','TractAsian','TractNHOPI',
                         'TractAIAN','TractOMultir','TractHispanic','TractHUNV','TractSNAP'], inplace=True)
# Out:
# C:\Users\joann\AppData\Local\Temp\ipykernel_24644\464002592.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df.drop(columns=['TractLOWI','TractKids','TractSeniors','TractWhite','TractBlack','TractAsian','TractNHOPI',

# %%
list(grouped_df.columns)
# Out:
# ['County',
#  'Urban',
#  'Pop2010',
#  'OHU2010',
#  'GroupQuartersFlag',
#  'NUMGQTRS',
#  'PCTGQTRS',
#  'HUNVFlag',
#  'LowIncomeTracts',
#  'PovertyRate',
#  'MedianFamilyIncome',
#  'LAhalfand10',
#  'PctLOWI',
#  'PctKids',
#  'PctSeniors',
#  'PctWhite',
#  'PctBlack',
#  'PctAsian',
#  'PctNHOPI',
#  'PctAIAN',
#  'PctOMultir',
#  'PctHispanic',
#  'PctHUNV',
#  'PctSNAP']

# %%
# Convert categorical data to numeric with `pd.get_dummies`  ***

grouped_df.drop(columns=["County"], inplace=True)
dummies_df = pd.get_dummies(grouped_df)
dummies_df
# Out:
# C:\Users\joann\AppData\Local\Temp\ipykernel_24644\3822044187.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df.drop(columns=["County"], inplace=True)
#        Urban  Pop2010  OHU2010  GroupQuartersFlag  NUMGQTRS  PCTGQTRS  \
# 35210      1     3041     1447                  0     252.0  8.286748
# 35211      1     4491     1813                  0      32.0  0.712536
# 35212      1     4868     1966                  0       0.0  0.000000
# 35213      1     3005     1316                  0       0.0  0.000000
# 35214      1     4148     1804                  0     188.0  4.532305
# ...      ...      ...      ...                ...       ...       ...
# 36539      0     3931     1518                  0      60.0  1.526329
# 36540      0     3371     1379                  0     118.0  3.500445
# 36541      0     2520     1075                  0     122.0  4.841270
# 36542      0     2517     1044                  0      49.0  1.946762
# 36543      0     2030      794                  0       1.0  0.049261
#
#        HUNVFlag  LowIncomeTracts  PovertyRate  MedianFamilyIncome  ...  \
# 35210         1                1    15.465227             63583.0  ...
# 35211         1                1     9.216193             66333.0  ...
# 35212         1                1    11.160431             61791.0  ...
# 35213         1                1    16.223776             47578.0  ...
# 35214         1                1    30.311740             49188.0  ...
# ...         ...              ...          ...                 ...  ...
# 36539         0                0     4.054739             82823.0  ...
# 36540         0                0    19.607843             70722.0  ...
# 36541         0                0    11.030741             70066.0  ...
# 36542         0                0     8.866583             72917.0  ...
# 36543         0                1    12.297893             64483.0  ...
#
#        PctSeniors  PctWhite  PctBlack  PctAsian  PctNHOPI   PctAIAN  \
# 35210    0.198948  0.898389  0.042749  0.008550  0.000000  0.016113
# 35211    0.127589  0.850367  0.064128  0.018704  0.000445  0.010465
# 35212    0.092646  0.663311  0.163722  0.050740  0.000411  0.017872
# 35213    0.175707  0.644260  0.193677  0.046256  0.000333  0.010982
# 35214    0.155014  0.867888  0.010608  0.011572  0.000241  0.062199
# ...           ...       ...       ...       ...       ...       ...
# 36539    0.133808  0.977105  0.004325  0.002544  0.000509  0.002289
# 36540    0.185702  0.876594  0.002077  0.004450  0.000297  0.080392
# 36541    0.254365  0.983730  0.002381  0.002778  0.000000  0.000397
# 36542    0.185538  0.974176  0.000795  0.001986  0.000000  0.004370
# 36543    0.146305  0.945813  0.000493  0.002956  0.002463  0.015271
#
#        PctOMultir  PctHispanic   PctHUNV   PctSNAP
# 35210    0.034199     0.044722  0.080237  0.065110
# 35211    0.055890     0.039635  0.029392  0.054999
# 35212    0.103944     0.118529  0.024240  0.033895
# 35213    0.104493     0.123794  0.110150  0.102829
# 35214    0.047493     0.017840  0.049421  0.115718
# ...           ...          ...       ...       ...
# 36539    0.013228     0.027983  0.015009  0.027983
# 36540    0.036191     0.035301  0.025808  0.040344
# 36541    0.010714     0.017460  0.025000  0.041667
# 36542    0.018673     0.025427  0.011919  0.026619
# 36543    0.033005     0.083744  0.014778  0.028571
#
# [1334 rows x 23 columns]

# %%
# Split our preprocessed data into our features and target arrays 
y = dummies_df.LAhalfand10.values
X = dummies_df.drop(columns="LAhalfand10").values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances ****
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# #### When the model below was first created and trained, "Accuracy" results were coming back at around 30%.
# #### Something had to be incorrect somewhere. First checked the dataset and discovered there were 8 places
# #### where "MedianFamilyIncome" was NaN spread across 3 different Minnesota counties. Used the .median()
# #### method above to fill in the NaN fields.
#
# #### Also, when looking at the .value_counts() from dummies, typically "0" count should be higher then "1" if nothing else, but even
# #### still, the data did not appear to be too balanced, so wasn't sure if that was going to be a challenge.
#
# #### Next, created a "First" and "Second" hidden layers with hidden_nodes_layer1 at 800 and ...layer2 at 500 and epochs below at
# #### 100. After running evertyhing, "Accuracy" was around 75%-76%! When training, the model did seem to be overfitting, so bumped
# #### the epochs down to 10. Also tried adding a "Third" hidden layer with 50 nodes, and "Accuracy" was still coming out at 76%-77%.
#
# #### Removed the first hidden layer below and also removed the "County" column and then saw "Accuracy" jump to 85.6% as indicated below.

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
# hidden_nodes_layer1 =  300
hidden_nodes_layer2 = 100
hidden_nodes_layer3 = 50

nn = tf.keras.models.Sequential()

# First hidden layer
#nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu", input_dim=number_input_features))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               2300
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 12501 (48.83 KB)
# Trainable params: 12501 (48.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
dummies_df["LAhalfand10"].value_counts() #dataset is imbalanced, usually 0 should be higher than 1
# Out:
# 1    940
# 0    394
# Name: LAhalfand10, dtype: int64

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=10)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 1s 1ms/step - loss: 0.5604 - accuracy: 0.6920
# Epoch 2/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4028 - accuracy: 0.8180
# Epoch 3/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3468 - accuracy: 0.8350
# Epoch 4/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3214 - accuracy: 0.8410
# Epoch 5/10
# 32/32 [==============================] - 0s 995us/step - loss: 0.3049 - accuracy: 0.8640
# Epoch 6/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2860 - accuracy: 0.8670
# Epoch 7/10
# 32/32 [==============================] - 0s 1000us/step - loss: 0.2809 - accuracy: 0.8730
# Epoch 8/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2780 - accuracy: 0.8720
# Epoch 9/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2657 - accuracy: 0.8730
# Epoch 10/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2572 - accuracy: 0.8830

# %%
type(fit_model)
# Out:
# keras.src.callbacks.History

# %%
fit_model.history  #plot loss function
# Out:
# {'loss': [0.5604481101036072,
#   0.402775377035141,
#   0.34681427478790283,
#   0.32136303186416626,
#   0.30488884449005127,
#   0.285959929227829,
#   0.280946284532547,
#   0.2779971659183502,
#   0.2657451927661896,
#   0.2572086751461029],
#  'accuracy': [0.6919999718666077,
#   0.8180000185966492,
#   0.8349999785423279,
#   0.8410000205039978,
#   0.8640000224113464,
#   0.8669999837875366,
#   0.8730000257492065,
#   0.871999979019165,
#   0.8730000257492065,
#   0.8830000162124634]}

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 11/11 - 0s - loss: 0.3448 - accuracy: 0.8533 - 127ms/epoch - 12ms/step
# Loss: 0.34482961893081665, Accuracy: 0.8532934188842773

# %%
grouped_df.columns.tolist()
# Out:
# ['Urban',
#  'Pop2010',
#  'OHU2010',
#  'GroupQuartersFlag',
#  'NUMGQTRS',
#  'PCTGQTRS',
#  'HUNVFlag',
#  'LowIncomeTracts',
#  'PovertyRate',
#  'MedianFamilyIncome',
#  'LAhalfand10',
#  'PctLOWI',
#  'PctKids',
#  'PctSeniors',
#  'PctWhite',
#  'PctBlack',
#  'PctAsian',
#  'PctNHOPI',
#  'PctAIAN',
#  'PctOMultir',
#  'PctHispanic',
#  'PctHUNV',
#  'PctSNAP']

# %%
# Create a DataFrame containing training history
plot_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the accuracy
plot_df.plot(y="accuracy")
plt.show()

# %%
loss_values = fit_model.history['loss']

epochs_range = range(1, len(loss_values) + 1)

plt.plot(epochs_range, loss_values, marker='o', linestyle='-')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.grid(True)
plt.show()
